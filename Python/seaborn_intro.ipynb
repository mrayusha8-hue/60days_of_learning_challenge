# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# #Loading built-in data

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# #Basic Plot Syntax

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %% [markdown]
# #Seaborn has 4 types of context('paper', notebook', 'talk', 'poster') which allows to override default parameters.
# #Platte: Set1 - bright & high-contrast colors(9)
#          Set2 - softer, more pastel-like colors(8)
#          Set3 - mix of soft and bold,varied hues(12)

# %%
#Scatter plot
sns.set_style("dark")
sns. set_context("notebook")
sns.scatterplot(data = penguins, x = "bill_length_mm", y ="bill_depth_mm", hue = "species",palette = "Dark2")
sns.despine(left = True)     #despine() removes the top and right spines from plots.(the borders around a plot)

# %%
sns.scatterplot(penguins, x = "species", y = "body_mass_g", hue = "island", style = "sex", alpha = 0.5) #alpha, used as there are overlapping points, ,it balances the opacity of the points
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#Strip plot
sns.stripplot(data = penguins, x = "species", y = "body_mass_g", hue = "island", dodge = True, jitter = True) #jitter used to spread randomly for more better readability
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#Swarm plot
sns.set_context("talk")
sns.stripplot(data = penguins, x = "species", y = "body_mass_g", hue = "island") 
sns.despine()

# %%
#Histogram
sns.set_context("notebook")
sns.histplot(data = penguins, x = "body_mass_g",hue = "sex", multiple = "stack" ) # plots histogram of body_mass_g with hue categories stacked within each bin
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
#Regression plot
sns.regplot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
#line plot
sns.lineplot(data = penguins, x = "body_mass_g", y = "flipper_length_mm")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#Bar plot
sns.barplot(data = penguins, x = "species", y = "body_mass_g", hue = "sex", palette = ["red", "blue"], estimator = np.median)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#Joint plot
sns.jointplot(data = penguins, x = "flipper_length_mm", y = "body_mass_g",kind = "reg")

# %%
#countplot -> used to show counts of observations in each categorical bin using bars
sns.countplot(data = penguins, x = "species", hue = "island", palette = "Set3")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#Box plot
sns.set_style("whitegrid")
sns.boxplot(data = penguins, x = "species", y = "body_mass_g", hue = "sex",  )
#findings of this plot: In the chinstrap species, demale lowest body mass
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#Pair plot -> used to visualize pairwise relationships in a dataset.
sns.pairplot(data = penguins, hue = "species", palette = "Dark2", diag_kind = "kde") #diag_kind = "kde" is used to plot the kernel density estimate on the diagonal subplots instead of histograms.
